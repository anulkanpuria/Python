# %%
import pandas as pd
btc = pd.read_csv('data/coin_Bitcoin.csv')

# %%
btc.set_index('Date', inplace=True)

# %%
btc.High.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
btc.sort_values('High', ascending=0, inplace=True)

# %%
btc
# Out:
#                       SNo     Name Symbol          High           Low  \
# Date
# 2021-04-14 23:59:59  2908  Bitcoin    BTC  64863.098908  61554.796690
# 2021-04-15 23:59:59  2909  Bitcoin    BTC  63821.672193  62208.964366
# 2021-04-13 23:59:59  2907  Bitcoin    BTC  63742.283337  59869.956293
# 2021-04-16 23:59:59  2910  Bitcoin    BTC  63594.720913  60222.532079
# 2021-04-17 23:59:59  2911  Bitcoin    BTC  62572.176051  60361.352179
# ...                   ...      ...    ...           ...           ...
# 2013-07-05 23:59:59    68  Bitcoin    BTC     80.000000     65.526001
# 2013-07-08 23:59:59    71  Bitcoin    BTC     80.000000     72.599998
# 2013-07-09 23:59:59    72  Bitcoin    BTC     78.300003     72.519997
# 2013-07-06 23:59:59    69  Bitcoin    BTC     75.000000     66.820000
# 2013-07-07 23:59:59    70  Bitcoin    BTC     74.561096     66.620003
#
#                              Open         Close        Volume     Marketcap
# Date
# ...

# %% [markdown]
# # Sorting Characters in Python
# * Sorting order ABCD...Zabc...z

# %%
titanic = pd.read_csv('data/titanic.csv')

# %%
titanic.sort_values('name', key=lambda col: col.str.lower())
# Out:
#       pclass  survived                              name     sex   age  sibsp  \
# 600        3         0               Abbing, Mr. Anthony    male    42      0
# 601        3         0     Abbott, Master. Eugene Joseph    male    13      0
# 602        3         0       Abbott, Mr. Rossmore Edward    male    16      1
# 603        3         1  Abbott, Mrs. Stanton (Rosa Hunt)  female    35      1
# 604        3         1       Abelseth, Miss. Karen Marie  female    16      0
# ...      ...       ...                               ...     ...   ...    ...
# 1304       3         0              Zabour, Miss. Hileni  female  14.5      1
# 1305       3         0             Zabour, Miss. Thamine  female     ?      1
# 1306       3         0         Zakarian, Mr. Mapriededer    male  26.5      0
# 1307       3         0               Zakarian, Mr. Ortin    male    27      0
# 1308       3         0                Zimmerman, Mr. Leo    male    29      0
#
# ...

# %%
countries = pd.read_csv('data/countries of the world.csv')

# %%
type(countries)
# Out:
# pandas.core.frame.DataFrame

# %%
countries.loc[0:10:2]
# Out:
#          Country                               Region  Population  \
# 0   Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 2       Algeria   NORTHERN AFRICA                        32930091
# 4       Andorra   WESTERN EUROPE                            71201
# 6      Anguilla               LATIN AMER. & CARIB           13477
# 8     Argentina               LATIN AMER. & CARIB        39921833
# 10        Aruba               LATIN AMER. & CARIB           71891
#
#     Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0           647500                       48,0                         0,00
# 2          2381740                       13,8                         0,04
# 4              468                      152,1                         0,00
# 6              102                      132,1                        59,80
# 8          2766890                       14,4                         0,18
# ...
