# %%
import pandas as pd
df = pd.read_csv('data/netflix_titles.csv', sep='|')

# %%
df.set_index('show_id', inplace=True)

# %%
df.loc['s2202', 'director'] = 'Greg Whiteley'

# %%
df.loc['s2202', 'director']
# Out:
# 'Greg Whiteley'

# %%
df.loc[['s2881', 's3601'], 'duration'] = 'Gone Too Soon'

# %%
df.loc[['s2881', 's3601']]
# Out:
#          Unnamed: 0     type                    title director  \
# show_id
# s2881          2880  TV Show  I Am Not Okay With This      NaN
# s3601          3600  TV Show                     GLOW      NaN
#
#                                                       cast        country  \
# show_id
# s2881    Sophia Lillis, Wyatt Oleff, Kathleen Rose Perk...  United States
# s3601    Alison Brie, Betty Gilpin, Marc Maron, Britney...  United States
#
#                 date_added  release_year rating       duration  \
# show_id
# s2881    February 26, 2020          2020  TV-MA  Gone Too Soon
# s3601       August 9, 2019          2019  TV-MA  Gone Too Soon
#
#                                            listed_in  \
# show_id
# s2881    TV Comedies, TV Dramas, TV Sci-Fi & Fantasy
# s3601                         TV Comedies, TV Dramas
#
#                                                description
# show_id
# s2881    Angsty Syd navigates high school awkwardness, ...
# ...

# %%
df.rename(columns={'release_year':'release_yr'})
#df.rename({'release_year':'release_yr'}, axis=1)
# Out:
#          Unnamed: 0     type                  title         director  \
# show_id
# s1                0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2                1  TV Show          Blood & Water              NaN
# s3                2  TV Show              Ganglands  Julien Leclercq
# s4                3  TV Show  Jailbirds New Orleans              NaN
# s5                4  TV Show           Kota Factory              NaN
# ...             ...      ...                    ...              ...
# s8803          8802    Movie                 Zodiac    David Fincher
# s8804          8803  TV Show            Zombie Dumb              NaN
# s8805          8804    Movie             Zombieland  Ruben Fleischer
# s8806          8805    Movie                   Zoom     Peter Hewitt
# s8807          8806    Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# ...

# %%
df['rating'].replace(['NR', 'UR'], 'No Rating').value_counts()
# Out:
# TV-MA        3207
# TV-14        2160
# TV-PG         863
# R             799
# PG-13         490
# TV-Y7         334
# TV-Y          307
# PG            287
# TV-G          220
# No Rating      83
# G              41
# TV-Y7-FV        6
# NC-17           3
# 74 min          1
# 84 min          1
# 66 min          1
# Name: rating, dtype: int64

# %%
df['is_fav'] = 'False'

# %%
favs = ['Young Royals', 'Dark', 'Big Mouth']
df.loc[df['title'].isin(favs), 'is_fav'] = True

# %%
df['is_fav'].value_counts()
# Out:
# False    8804
# True        3
# Name: is_fav, dtype: int64

# %%
df.describe(include='all')
# Out:
#          Unnamed: 0   type                 title       director  \
# count   8807.000000   8807                  8807           6174
# unique          NaN      2                  8807           4528
# top             NaN  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq            NaN   6131                     1             19
# mean    4403.000000    NaN                   NaN            NaN
# std     2542.506244    NaN                   NaN            NaN
# min        0.000000    NaN                   NaN            NaN
# 25%     2201.500000    NaN                   NaN            NaN
# 50%     4403.000000    NaN                   NaN            NaN
# 75%     6604.500000    NaN                   NaN            NaN
# max     8806.000000    NaN                   NaN            NaN
#
#                       cast        country       date_added  release_year  \
# count                 7982           7976             8797   8807.000000
# ...
